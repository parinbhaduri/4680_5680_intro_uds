# %% [markdown]
# # Homework 1
#
# ## Overview
# This homework will walk you through the process of geospatial data analysis under the short-term rental market (Airbnb) context in New York City. Through this practice, you will get more familiar with pandas, numpy, geopandas, seaborn, and matplotlib modules to retrieve, clean, and visulaize geospatial data.
#
# ## Grading
# Each exercise will be graded based on the following rubrics:
# - 2 points. Completed the task, presented the expected results, and codes were well documented and explained.
# - 1 point. Completed the task with some disparity from the expected results.
# - 0 point. Did not complete the excercise.
#
# ## Late submission policy
# For late submission, every extra day after the due date will lead to 20% off of your points. Less than a day will be counted as one day. All submissions after the TA team posts the answers will not be accepted.

# %% [markdown]
# ## 1. Retrieve Data
# ### 1.1 Read the Airbnb Data (2 points)
# The first step is to retrieve two datasets from oline resrouces and read one given dataset. Two online resources include the Airbnb lisitng information and the census tract of New York City.
#
# Go to the Airbnb data warehouse http://insideairbnb.com/get-the-data/ and find New York City section:
# ![image.png](attachment:image.png)
#
# Right click on the hyperlink of the first row and copy the link. Name the dataframe as **listing_raw**. Present the first 5 rows below.

# %%
#Import packages
import pandas as pd
import numpy as np
import geopandas as gpd
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/3805325496.py:4: UserWarning: Shapely 2.0 is installed, but because PyGEOS is also installed, GeoPandas will still use PyGEOS by default for now. To force to use and test Shapely 2.0, you have to set the environment variable USE_PYGEOS=0. You can do this before starting the Python process, or in your code before importing geopandas:
#
# import os
# os.environ['USE_PYGEOS'] = '0'
# import geopandas
#
# In a future release, GeoPandas will switch to using Shapely by default. If you are using PyGEOS directly (calling PyGEOS functions on geometries from GeoPandas), this will then stop working and you are encouraged to migrate from PyGEOS to Shapely 2.0 (https://shapely.readthedocs.io/en/latest/migration_pygeos.html).
#   import geopandas as gpd

# %%
### enter your code here
#Read in data
listing_raw = pd.read_csv("http://data.insideairbnb.com/united-states/ny/new-york-city/2022-12-04/data/listings.csv.gz")

listing_raw.head()
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/782712553.py:3: DtypeWarning: Columns (68) have mixed types. Specify dtype option on import or set low_memory=False.
#   listing_raw = pd.read_csv("http://data.insideairbnb.com/united-states/ny/new-york-city/2022-12-04/data/listings.csv.gz")
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20221204162430   2022-12-05
# 1  5203  https://www.airbnb.com/rooms/5203  20221204162430   2022-12-05
# 2  5136  https://www.airbnb.com/rooms/5136  20221204162430   2022-12-04
# 3  5121  https://www.airbnb.com/rooms/5121  20221204162430   2022-12-05
# 4  6848  https://www.airbnb.com/rooms/6848  20221204162430   2022-12-05
#
#             source                                      name  \
# 0      city scrape                     Skylit Midtown Castle
# 1  previous scrape        Cozy Clean Guest Room - Family Apt
# 2      city scrape  Spacious Brooklyn Duplex, Patio + Garden
# 3      city scrape                           BlissArtsSpace!
# 4      city scrape          Only 2 stops to Manhattan studio
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Our best guests are seeking a safe, clean, spa...
# 2  We welcome you to stay in our lovely 2 br dupl...
# 3  One room available for rent in a 2 bedroom apt...
# 4  Comfortable studio apartment with super comfor...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1  Our neighborhood is full of restaurants and ca...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845  ...
# 1  https://a0.muscache.com/pictures/103776/b37157...     7490  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...     7378  ...
# 3  https://a0.muscache.com/pictures/2090980c-b68e...     7356  ...
# 4  https://a0.muscache.com/pictures/e4f031a7-f146...    15991  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.80                   4.81                4.40
# 1                        4.95                   4.94                4.92
# 2                        5.00                   4.67                5.00
# 3                        4.91                   4.47                4.52
# 4                        4.80                   4.67                4.56
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              3
# 1     NaN                f                              1
# 2     NaN                f                              1
# 3     NaN                f                              2
# 4     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           3
# 1                                           0
# 2                                           1
# 3                                           0
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.31
# 1                                           0              0.73
# 2                                           0              0.03
# 3                                           0              0.30
# 4                                           0              1.13
#
# [5 rows x 75 columns]

# %% [markdown]
# ### 1.2 Retrieve the Census Tracts of New York City (2 points)
# Go to NYC Department of planning (https://www.nyc.gov/site/planning/data-maps/open-data/census-download-metadata.page). Unfold the *Census Blocks and Tracts* tab and copy the *GeoJSON* link of *2020 Census Tracts (Clipped to shoreline)*.
# ![image-2.png](attachment:image-2.png)
#
# After reading GeoJSON file from the url, assign the dataframe with WGS 84 Geodetic System (epsg = 4326) and name the dataframe as **ct**. Show the first 5 rows of the **ct**.

# %%
url = "https://services5.arcgis.com/GfwWNkhOj9bNBqoJ/arcgis/rest/services/NYC_Census_Tracts_for_2020_US_Census/FeatureServer/0/query?where=1=1&outFields=*&outSR=4326&f=pgeojson"
ct = gpd.read_file(url).to_crs(epsg = 4326)
ct.head()
# Out:
#    OBJECTID CTLabel BoroCode   BoroName  CT2020 BoroCT2020 CDEligibil  \
# 0         1       1        1  Manhattan  000100    1000100       None
# 1         2    2.01        1  Manhattan  000201    1000201       None
# 2         3       6        1  Manhattan  000600    1000600       None
# 3         4   14.01        1  Manhattan  001401    1001401       None
# 4         5   14.02        1  Manhattan  001402    1001402       None
#
#                                              NTAName NTA2020 CDTA2020  \
# 0  The Battery-Governors Island-Ellis Island-Libe...  MN0191     MN01
# 1                              Chinatown-Two Bridges  MN0301     MN03
# 2                              Chinatown-Two Bridges  MN0301     MN03
# 3                                    Lower East Side  MN0302     MN03
# 4                                    Lower East Side  MN0302     MN03
#
#                                             CDTANAME        GEOID  \
# 0  MN01 Financial District-Tribeca (CD 1 Equivalent)  36061000100
# 1   MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061000201
# 2   MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061000600
# 3   MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061001401
# 4   MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061001402
#
#     Shape__Area  Shape__Length  \
# 0  1.844391e+06   11022.881754
# 1  9.723121e+05    4754.495247
# 2  2.582705e+06    6976.286456
# 3  1.006117e+06    5075.332000
# 4  1.226206e+06    4459.156019
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...
# 1  POLYGON ((-73.98450 40.70952, -73.98655 40.709...
# 2  POLYGON ((-73.99022 40.71441, -73.98934 40.714...
# 3  POLYGON ((-73.98837 40.71645, -73.98754 40.716...
# 4  POLYGON ((-73.98507 40.71909, -73.98423 40.718...

# %% [markdown]
# ### 1.3 Read the Local Dataset (2 points)
# Read the demographic information from the given csv file and name it as **demo**. Show the information of **demo** with the function .info().

# %%
### enter your code here
demo = pd.read_csv('acs_nyc.csv')
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2327 entries, 0 to 2326
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GEOID        2327 non-null   int64
#  1   hh_income    2196 non-null   float64
#  2   house_value  1966 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 54.7 KB

# %% [markdown]
# ## 2. Data Wrangling/Cleaning
# ### 2.1 Rename the Columns of **ct** (2 points)
# Rename the column of *BoroName* as *borough_ct* and column of *NTAName* as *tract_ct*. Show the first 5 rows of **ct**.

# %%
### enter your code here
ct = ct.rename(columns = {'BoroName':'borough_ct', 'NTAName':'tract_ct'})

ct.head()
# Out:
#    OBJECTID CTLabel BoroCode borough_ct  CT2020 BoroCT2020 CDEligibil  \
# 0         1       1        1  Manhattan  000100    1000100       None
# 1         2    2.01        1  Manhattan  000201    1000201       None
# 2         3       6        1  Manhattan  000600    1000600       None
# 3         4   14.01        1  Manhattan  001401    1001401       None
# 4         5   14.02        1  Manhattan  001402    1001402       None
#
#                                             tract_ct NTA2020 CDTA2020  \
# 0  The Battery-Governors Island-Ellis Island-Libe...  MN0191     MN01
# 1                              Chinatown-Two Bridges  MN0301     MN03
# 2                              Chinatown-Two Bridges  MN0301     MN03
# 3                                    Lower East Side  MN0302     MN03
# 4                                    Lower East Side  MN0302     MN03
#
#                                             CDTANAME        GEOID  \
# 0  MN01 Financial District-Tribeca (CD 1 Equivalent)  36061000100
# 1   MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061000201
# 2   MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061000600
# 3   MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061001401
# 4   MN03 Lower East Side-Chinatown (CD 3 Equivalent)  36061001402
#
#     Shape__Area  Shape__Length  \
# 0  1.844391e+06   11022.881754
# 1  9.723121e+05    4754.495247
# 2  2.582705e+06    6976.286456
# 3  1.006117e+06    5075.332000
# 4  1.226206e+06    4459.156019
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...
# 1  POLYGON ((-73.98450 40.70952, -73.98655 40.709...
# 2  POLYGON ((-73.99022 40.71441, -73.98934 40.714...
# 3  POLYGON ((-73.98837 40.71645, -73.98754 40.716...
# 4  POLYGON ((-73.98507 40.71909, -73.98423 40.718...

# %% [markdown]
# ### 2.2 Generate GeometryArray from Latitude and Longitude (2 points)
# To conduct geospatial analysis, the geospatial information must be specified. For example, **listing_raw** dataframe contains *latitude* and *longitude* columns, but both columns are treated as the same as the other numeric columns. To specify such geospatial information, an GeometryArray, which contains arrays of positional coordinates to describe Points, needs to be generated.
#
# Now generate an GeometryArray based on the *latitude* and *longitude* columns in **listing_raw** and name the GeometryArray as **geometry**.

# %%
geometry = gpd.points_from_xy(listing_raw["longitude"], listing_raw["latitude"])

# %% [markdown]
# ### 2.3 Transform Dataframe into Geo-dataframe (2 points)
# A dataframe can be transformed into a geo-dataframe by adding *geometry* column, which must contain GeometryArray or GeoSeries. With the *geometry* generated above, transform **listing_raw** dataframe into **listing_g** geo-dataframe and assign the dataframe with WGS 84 Geodetic System (epsg = 4326). Present the first 5 rows.

# %%
### enter your code here
#convert dataframe to geodataframe
listings_g = gpd.GeoDataFrame(listing_raw, geometry = geometry, crs = 4326)

#Present first 5 rows
listings_g.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20221204162430   2022-12-05
# 1  5203  https://www.airbnb.com/rooms/5203  20221204162430   2022-12-05
# 2  5136  https://www.airbnb.com/rooms/5136  20221204162430   2022-12-04
# 3  5121  https://www.airbnb.com/rooms/5121  20221204162430   2022-12-05
# 4  6848  https://www.airbnb.com/rooms/6848  20221204162430   2022-12-05
#
#             source                                      name  \
# 0      city scrape                     Skylit Midtown Castle
# 1  previous scrape        Cozy Clean Guest Room - Family Apt
# 2      city scrape  Spacious Brooklyn Duplex, Patio + Garden
# 3      city scrape                           BlissArtsSpace!
# 4      city scrape          Only 2 stops to Manhattan studio
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Our best guests are seeking a safe, clean, spa...
# 2  We welcome you to stay in our lovely 2 br dupl...
# 3  One room available for rent in a 2 bedroom apt...
# 4  Comfortable studio apartment with super comfor...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1  Our neighborhood is full of restaurants and ca...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845  ...
# 1  https://a0.muscache.com/pictures/103776/b37157...     7490  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...     7378  ...
# 3  https://a0.muscache.com/pictures/2090980c-b68e...     7356  ...
# 4  https://a0.muscache.com/pictures/e4f031a7-f146...    15991  ...
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   4.81                4.40     NaN                f
# 1                   4.94                4.92     NaN                f
# 2                   4.67                5.00     NaN                f
# 3                   4.47                4.52     NaN                f
# 4                   4.67                4.56     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              3                                           3
# 1                              1                                           0
# 2                              1                                           1
# 3                              2                                           0
# 4                              1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                           0              0.31
# 1                                           0              0.73
# 2                                           0              0.03
# 3                                           0              0.30
# 4                                           0              1.13
#
#                      geometry
# 0  POINT (-73.98559 40.75356)
# 1  POINT (-73.96751 40.80380)
# 2  POINT (-73.99454 40.66265)
# 3  POINT (-73.95512 40.68535)
# 4  POINT (-73.95342 40.70935)
#
# [5 rows x 76 columns]

# %% [markdown]
# ### 2.4 Remove nan Values (2 points)
# Remove all n/a values from *beds* column and drop *bathrooms, calendar_updated, license, and neighbourhood* columns in **listing_g** and name the new dataframe as **listing_s**. Show the first 5 rows of **listing_s**.

# %%
### enter your code here
#Remove NA values in beds columns and drop unwanted columns from dataframe
listing_s = listings_g[listings_g['beds'].notna()].drop(columns= ['bathrooms','calendar_updated','license','neighbourhood'])

#Show first 5 rows
listing_s.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20221204162430   2022-12-05
# 1  5203  https://www.airbnb.com/rooms/5203  20221204162430   2022-12-05
# 2  5136  https://www.airbnb.com/rooms/5136  20221204162430   2022-12-04
# 3  5121  https://www.airbnb.com/rooms/5121  20221204162430   2022-12-05
# 4  6848  https://www.airbnb.com/rooms/6848  20221204162430   2022-12-05
#
#             source                                      name  \
# 0      city scrape                     Skylit Midtown Castle
# 1  previous scrape        Cozy Clean Guest Room - Family Apt
# 2      city scrape  Spacious Brooklyn Duplex, Patio + Garden
# 3      city scrape                           BlissArtsSpace!
# 4      city scrape          Only 2 stops to Manhattan studio
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Our best guests are seeking a safe, clean, spa...
# 2  We welcome you to stay in our lovely 2 br dupl...
# 3  One room available for rent in a 2 bedroom apt...
# 4  Comfortable studio apartment with super comfor...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1  Our neighborhood is full of restaurants and ca...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845  ...
# 1  https://a0.muscache.com/pictures/103776/b37157...     7490  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...     7378  ...
# 3  https://a0.muscache.com/pictures/2090980c-b68e...     7356  ...
# 4  https://a0.muscache.com/pictures/e4f031a7-f146...    15991  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.80                   4.81                4.40
# 1                        4.95                   4.94                4.92
# 2                        5.00                   4.67                5.00
# 3                        4.91                   4.47                4.52
# 4                        4.80                   4.67                4.56
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              3
# 1                f                              1
# 2                f                              1
# 3                f                              2
# 4                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           3
# 1                                           0
# 2                                           1
# 3                                           0
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                           0              0.31
# 1                                           0              0.73
# 2                                           0              0.03
# 3                                           0              0.30
# 4                                           0              1.13
#
#                      geometry
# 0  POINT (-73.98559 40.75356)
# 1  POINT (-73.96751 40.80380)
# 2  POINT (-73.99454 40.66265)
# 3  POINT (-73.95512 40.68535)
# 4  POINT (-73.95342 40.70935)
#
# [5 rows x 72 columns]

# %% [markdown]
# ### 2.5 Formatting Column Values (2 points)
# For statistical purpose, *price* in the Airbnb listing table must be numeric. In the following cell, remove dollar sign and comma from *price* column in **listing_s** and then transforme the column into float type. Show the first 5 rows of listing_s.

# %%
### enter your code here
#Remove unwanted symbols and change column type to float
listing_s['price'] = listing_s['price'].str.replace("$","").str.replace(",","").astype(float)

listing_s.head()
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/1800536460.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   listing_s['price'] = listing_s['price'].str.replace("$","").str.replace(",","").astype(float)
#      id                        listing_url       scrape_id last_scraped  \
# 0  2595  https://www.airbnb.com/rooms/2595  20221204162430   2022-12-05
# 1  5203  https://www.airbnb.com/rooms/5203  20221204162430   2022-12-05
# 2  5136  https://www.airbnb.com/rooms/5136  20221204162430   2022-12-04
# 3  5121  https://www.airbnb.com/rooms/5121  20221204162430   2022-12-05
# 4  6848  https://www.airbnb.com/rooms/6848  20221204162430   2022-12-05
#
#             source                                      name  \
# 0      city scrape                     Skylit Midtown Castle
# 1  previous scrape        Cozy Clean Guest Room - Family Apt
# 2      city scrape  Spacious Brooklyn Duplex, Patio + Garden
# 3      city scrape                           BlissArtsSpace!
# 4      city scrape          Only 2 stops to Manhattan studio
#
#                                          description  \
# 0  Beautiful, spacious skylit studio in the heart...
# 1  Our best guests are seeking a safe, clean, spa...
# 2  We welcome you to stay in our lovely 2 br dupl...
# 3  One room available for rent in a 2 bedroom apt...
# 4  Comfortable studio apartment with super comfor...
#
#                                neighborhood_overview  \
# 0  Centrally located in the heart of Manhattan ju...
# 1  Our neighborhood is full of restaurants and ca...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/f0813a11-40b2...     2845  ...
# 1  https://a0.muscache.com/pictures/103776/b37157...     7490  ...
# 2  https://a0.muscache.com/pictures/miso/Hosting-...     7378  ...
# 3  https://a0.muscache.com/pictures/2090980c-b68e...     7356  ...
# 4  https://a0.muscache.com/pictures/e4f031a7-f146...    15991  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.80                   4.81                4.40
# 1                        4.95                   4.94                4.92
# 2                        5.00                   4.67                5.00
# 3                        4.91                   4.47                4.52
# 4                        4.80                   4.67                4.56
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              3
# 1                f                              1
# 2                f                              1
# 3                f                              2
# 4                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           3
# 1                                           0
# 2                                           1
# 3                                           0
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            1
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                           0              0.31
# 1                                           0              0.73
# 2                                           0              0.03
# 3                                           0              0.30
# 4                                           0              1.13
#
#                      geometry
# 0  POINT (-73.98559 40.75356)
# 1  POINT (-73.96751 40.80380)
# 2  POINT (-73.99454 40.66265)
# 3  POINT (-73.95512 40.68535)
# 4  POINT (-73.95342 40.70935)
#
# [5 rows x 72 columns]

# %% [markdown]
# ### 2.6 Unify Column Types of *GEOID* in **ct** and **demo** (2 points)
#
# To merge **ct** and **demo**, *GEOID* will be used as the primary key for both dataframes. However, *GEOID* in **ct** is object but *GEOID* in **demo** is int. Therefore, *GEOID* in both dataframes need to be converted into string.

# %%
### enter your code here
demo['GEOID'] = demo['GEOID'].astype(str)

#Ensure both columns are of same type
demo['GEOID'].dtypes == ct['GEOID'].dtypes
# Out:
# True

# %% [markdown]
# ### 2.7 Merge **ct** and **demo** Dataframes (2 points)
# Once *GEOID* in both dataframes are in the same type, **ct** and **demo** can be joined. Select only *GEOID*, *borough_ct*, *tract_ct*, and *geometry* columns from **ct** and merge them into **demo**. Present the first 5 rows of the merged dataframe **ct_demo** below.

# %%
### enter your code here
ct_demo = ct[['GEOID', 'borough_ct', 'tract_ct', 'geometry']].merge(demo, on = 'GEOID')

ct_demo.head()
# Out:
#          GEOID borough_ct                                           tract_ct  \
# 0  36061000100  Manhattan  The Battery-Governors Island-Ellis Island-Libe...
# 1  36061000201  Manhattan                              Chinatown-Two Bridges
# 2  36061000600  Manhattan                              Chinatown-Two Bridges
# 3  36061001401  Manhattan                                    Lower East Side
# 4  36061001402  Manhattan                                    Lower East Side
#
#                                             geometry  hh_income  house_value
# 0  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...        NaN          NaN
# 1  POLYGON ((-73.98450 40.70952, -73.98655 40.709...    32286.0          NaN
# 2  POLYGON ((-73.99022 40.71441, -73.98934 40.714...    19692.0     776000.0
# 3  POLYGON ((-73.98837 40.71645, -73.98754 40.716...    95515.0     839300.0
# 4  POLYGON ((-73.98507 40.71909, -73.98423 40.718...    33793.0          NaN

# %% [markdown]
# Though **ct** has been read as geo-dataframe in step 1.2, the merged dataframe **ct_demo** is treated as a dataframe by default. To transform **ct_demo** into a geo-dataframe, you only need to specify the *geometry* in **ct** as the *geometry* of **ct_demo**. Name the new geo-dataframe as **ct_demo_g** and present the first 5 rows.

# %%
### enter your code here
ct_demo_g = gpd.GeoDataFrame(ct_demo, geometry = ct['geometry'], crs = 4326)

ct_demo_g.head()
# Out:
#          GEOID borough_ct                                           tract_ct  \
# 0  36061000100  Manhattan  The Battery-Governors Island-Ellis Island-Libe...
# 1  36061000201  Manhattan                              Chinatown-Two Bridges
# 2  36061000600  Manhattan                              Chinatown-Two Bridges
# 3  36061001401  Manhattan                                    Lower East Side
# 4  36061001402  Manhattan                                    Lower East Side
#
#                                             geometry  hh_income  house_value
# 0  MULTIPOLYGON (((-74.04388 40.69020, -74.04351 ...        NaN          NaN
# 1  POLYGON ((-73.98450 40.70952, -73.98655 40.709...    32286.0          NaN
# 2  POLYGON ((-73.99022 40.71441, -73.98934 40.714...    19692.0     776000.0
# 3  POLYGON ((-73.98837 40.71645, -73.98754 40.716...    95515.0     839300.0
# 4  POLYGON ((-73.98507 40.71909, -73.98423 40.718...    33793.0          NaN

# %% [markdown]
# ### 2.8 Merge Dataframes by Spatial Join (2 points)
# Now all information has been stored in geo-dataframe: the census tract and demographic information have been merged into **ct_demo_g** and the Airbnb listing in **listing_s**. However, **ct_demo_g** is based on census tracts (polygons) while **listing_s** is on points. To locate the listing at the census tract level, you are asked to spatial join **ct_demo_g** to **listing_s** if the apartment/house falls into a census tract. Name this new geo-dataframe as **listing**. Remember *geometry* in **listing** should be Points.  Show the first 5 rows below.

# %%
listing = gpd.tools.sjoin(listing_s, ct_demo_g, how = 'left')

listing.head()
# Out:
#                        id                                      listing_url  \
# 0                    2595                https://www.airbnb.com/rooms/2595
# 1                    5203                https://www.airbnb.com/rooms/5203
# 2                    5136                https://www.airbnb.com/rooms/5136
# 3                    5121                https://www.airbnb.com/rooms/5121
# 4                    6848                https://www.airbnb.com/rooms/6848
# ...                   ...                                              ...
# 41528  772683159414917117  https://www.airbnb.com/rooms/772683159414917117
# 41529  772705452516314073  https://www.airbnb.com/rooms/772705452516314073
# 41530  772710779275911753  https://www.airbnb.com/rooms/772710779275911753
# 41531  772714221060214808  https://www.airbnb.com/rooms/772714221060214808
# 41532  772716724205003579  https://www.airbnb.com/rooms/772716724205003579
#
#             scrape_id last_scraped           source  \
# 0      20221204162430   2022-12-05      city scrape
# 1      20221204162430   2022-12-05  previous scrape
# 2      20221204162430   2022-12-04      city scrape
# 3      20221204162430   2022-12-05      city scrape
# 4      20221204162430   2022-12-05      city scrape
# ...               ...          ...              ...
# 41528  20221204162430   2022-12-05      city scrape
# 41529  20221204162430   2022-12-05      city scrape
# 41530  20221204162430   2022-12-05      city scrape
# 41531  20221204162430   2022-12-04      city scrape
# 41532  20221204162430   2022-12-05      city scrape
#
#                                            name  \
# 0                         Skylit Midtown Castle
# 1            Cozy Clean Guest Room - Family Apt
# 2      Spacious Brooklyn Duplex, Patio + Garden
# 3                               BlissArtsSpace!
# 4              Only 2 stops to Manhattan studio
# ...                                         ...
# 41528                                   Dahiari
# 41529                        Beautiful Basement
# 41530                Central Park Close By - 24
# 41531                   Good Vibes at The Bronx
# 41532         2 bedroom Condo near West Village
#
#                                              description  \
# 0      Beautiful, spacious skylit studio in the heart...
# 1      Our best guests are seeking a safe, clean, spa...
# 2      We welcome you to stay in our lovely 2 br dupl...
# 3      One room available for rent in a 2 bedroom apt...
# 4      Comfortable studio apartment with super comfor...
# ...                                                  ...
# 41528  Desconecta de tus preocupaciones en este espac...
# 41529  Your family will be close to everything when y...
# 41530  This is a Three-Bedroom Apartment. You will ha...
# 41531  Keep it simple at this peaceful and centrally-...
# 41532  This beautifully decorated condo will give you...
#
#                                    neighborhood_overview  \
# 0      Centrally located in the heart of Manhattan ju...
# 1      Our neighborhood is full of restaurants and ca...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 41528                                                NaN
# 41529                                                NaN
# 41530                                                NaN
# 41531                                                NaN
# 41532                                                NaN
#
#                                              picture_url    host_id  ...  \
# 0      https://a0.muscache.com/pictures/f0813a11-40b2...       2845  ...
# 1      https://a0.muscache.com/pictures/103776/b37157...       7490  ...
# 2      https://a0.muscache.com/pictures/miso/Hosting-...       7378  ...
# 3      https://a0.muscache.com/pictures/2090980c-b68e...       7356  ...
# 4      https://a0.muscache.com/pictures/e4f031a7-f146...      15991  ...
# ...                                                  ...        ...  ...
# 41528  https://a0.muscache.com/pictures/miso/Hosting-...  125534010  ...
# 41529  https://a0.muscache.com/pictures/miso/Hosting-...  338424773  ...
# 41530  https://a0.muscache.com/pictures/miso/Hosting-...    2653479  ...
# 41531  https://a0.muscache.com/pictures/miso/Hosting-...  421264574  ...
# 41532  https://a0.muscache.com/pictures/miso/Hosting-...  481177884  ...
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                1
# 2                                                0
# 3                                                2
# 4                                                0
# ...                                            ...
# 41528                                            0
# 41529                                            1
# 41530                                           35
# 41531                                            0
# 41532                                            0
#
#       calculated_host_listings_count_shared_rooms reviews_per_month  \
# 0                                               0              0.31
# 1                                               0              0.73
# 2                                               0              0.03
# 3                                               0              0.30
# 4                                               0              1.13
# ...                                           ...               ...
# 41528                                           0               NaN
# 41529                                           0               NaN
# 41530                                           0               NaN
# 41531                                           0               NaN
# 41532                                           0               NaN
#
#                          geometry index_right        GEOID borough_ct  \
# 0      POINT (-73.98559 40.75356)        72.0  36061011300  Manhattan
# 1      POINT (-73.96751 40.80380)       132.0  36061019500  Manhattan
# 2      POINT (-73.99454 40.66265)      2298.0  36047014500   Brooklyn
# 3      POINT (-73.95512 40.68535)      1576.0  36047022900   Brooklyn
# 4      POINT (-73.95342 40.70935)      1845.0  36047052700   Brooklyn
# ...                           ...         ...          ...        ...
# 41528  POINT (-73.90065 40.87094)       300.0  36005026702      Bronx
# 41529  POINT (-73.80467 40.69891)       545.0  36081020800     Queens
# 41530  POINT (-73.96238 40.80259)      1217.0  36061019701  Manhattan
# 41531  POINT (-73.84789 40.82807)       201.0  36005007800      Bronx
# 41532  POINT (-73.99730 40.74003)        43.0  36061008100  Manhattan
#
#                                         tract_ct hh_income house_value
# 0                           Midtown-Times Square   81667.0    645800.0
# 1               Upper West Side-Manhattan Valley  105234.0   1044300.0
# 2                             Sunset Park (West)  106667.0    913600.0
# 3                      Bedford-Stuyvesant (West)  122989.0   1196700.0
# 4                                   Williamsburg   61966.0   1606700.0
# ...                                          ...       ...         ...
# 41528  Kingsbridge Heights-Van Cortlandt Village   46098.0    624600.0
# 41529                                    Jamaica   72574.0    753100.0
# 41530                        Morningside Heights   44154.0         NaN
# 41531                      Castle Hill-Unionport   54615.0    475400.0
# 41532                       Chelsea-Hudson Yards  144375.0   1168500.0
#
# [40592 rows x 78 columns]

# %% [markdown]
# ## 3. Data Analysis
# ### 3.1 Mean Listing Price by Borough (2 points)
# Find the mean listing price in each borough of New York City and list them below.

# %%
### enter your code here
listing.groupby('borough_ct').mean()['price']
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/2295737171.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   listing.groupby('borough_ct').mean()['price']
# borough_ct
# Bronx            183.198187
# Brooklyn         172.757595
# Manhattan        302.844283
# Queens           134.593544
# Staten Island    326.007595
# Name: price, dtype: float64

# %% [markdown]
# ### 3.2 The Most and Least Expensive Census Tracts in NYC (2 points)
# Find the 5 most expensive and the 5 least expensive census tracts based on the median price across New York City. You can present the results in seperate cells.

# %%
### enter your code here
#Group by Census Tracts using GEOID
#Sort by median price and get least Expensive Census Tracts.
listing.groupby('GEOID').median()['price'].sort_values().head()
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/1806384265.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   listing.groupby('GEOID').median()['price'].sort_values().head()
# GEOID
# 36081047802    16.0
# 36047043200    26.0
# 36047021400    29.0
# 36061024302    29.0
# 36005007000    30.0
# Name: price, dtype: float64

# %%
#Repeat above process with Most Expensive Census Tracts
listing.groupby('GEOID').median()['price'].sort_values(ascending = False).head()
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/3541669200.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   listing.groupby('GEOID').median()['price'].sort_values(ascending = False).head()
# GEOID
# 36005011900    5024.0
# 36005030900    2000.0
# 36005018400    2000.0
# 36047001300    1319.0
# 36047059800    1057.5
# Name: price, dtype: float64

# %% [markdown]
# ### 3.3 The Most and Least Expensive Census Tracts in Manhattan (2 points)
# Find the 5 most expensive neighborhoods (using median price) in Manhattan borough. You can present the results in seperate cells. Are they consistent with the 5 most expensive neighborhoods in New York City?

# %%
#Filter dataframe by borough_ct to select rows located in manhattan
listing_manhat = listing[listing['borough_ct'] == 'Manhattan']
#Repeat process in 3.2 for the newly created dataframe
listing_manhat.groupby('GEOID').median()['price'].sort_values().head()
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/1166080214.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   listing_manhat.groupby('GEOID').median()['price'].sort_values().head()
# GEOID
# 36061024302    29.0
# 36061029100    41.0
# 36061026700    48.0
# 36061026900    56.0
# 36061023502    60.0
# Name: price, dtype: float64

# %%
### enter your code here

#For most expensive neighborhoods in Manhattan:
listing_manhat.groupby('GEOID').median()['price'].sort_values(ascending = False).head()
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/897809291.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   listing_manhat.groupby('GEOID').median()['price'].sort_values(ascending = False).head()
# GEOID
# 36061010200    933.0
# 36061011900    923.0
# 36061011300    698.5
# 36061001300    641.0
# 36061010100    600.0
# Name: price, dtype: float64

# %% [markdown]
# These are not the same census tracts as calculated when looking at all neighborhoods in New York City. The most expensive Census Tracts in all of New York City have a higher median listing price than the most expensive Census Tracts in Manhattan. However, there does seem to be some unique listings in smaller census tracts that may be outliers in the overall distribution.

# %% [markdown]
# ### 3.4 The Number of Listing in Each Census Tract (2 points)
# Calculate the number of listing in each census tract using group_by function. Add this new column to **ct_demo_g** and create a new geo-dataframe **ct_demo_g_count**. Show the full list below.

# %%
### enter your code here
#Give Series a name
tract_list_count = listing.groupby('GEOID').size().rename("tract_list_count")

ct_demo_g_count = ct_demo_g.merge(tract_list_count, left_on = 'GEOID', right_index = True)

# %% [markdown]
# ## 4 Visualize Data
# ### 4.1 Relationship between the Price and Household Income (2 points)
# *hh_income* column contains the median household income by each census tract. Use the median listing price as the y axis and the household income as the x axis to draw scatter plot below.

# %%
### enter your code here
import matplotlib.pyplot as plt

hh_income = ct_demo_g_count['hh_income']

median_price = listing.groupby('GEOID').median()['price']

plt.scatter(hh_income, median_price)
plt.xlabel("Median Household Income")
plt.ylabel("Median Listing Price")
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/3288381030.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_price = listing.groupby('GEOID').median()['price']
# Text(0, 0.5, 'Median Listing Price')

# %% [markdown]
# ### 4.2 Relationship between the Price and Housing Value (2 points)
# *house_value* column contains the median housing value by each census tract. Use the median listing price as the y axis and the housing value as the x axis to draw scatter plot below.

# %%
### enter your code here
house_value = ct_demo_g_count['house_value']
median_price = listing.groupby('GEOID').median()['price']
plt.scatter(house_value, median_price)
plt.xlabel("Median Household Value")
plt.ylabel("Median Listing Price")
# Out:
# /var/folders/c5/dps3lj6n2sz8zkk_381lj9b1hnpv4f/T/ipykernel_94416/2962803586.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_price = listing.groupby('GEOID').median()['price']
# Text(0, 0.5, 'Median Listing Price')

# %% [markdown]
# ### 4.3 Mapping the Listing and Census Tracts (8 points)
# Plot all the listing and census tracts on the same figure.
# - Change the title to *2022 New York City Airbnb Listing* and name the x-y axis as longitude and latitude. (2 points)
#
# Out of aesthetic purpose,
# - Change the transparency of census tracts and listing points to 0.2. (2 points)
# - Change the size of listing points to 0.4. (2 points)
# - Add *grey* edge color to census tracts. (2 points)
#
# Show your map below.

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(figsize=(6, 6))
plt.title("2022 New York City Airbnb Listing")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

ct_demo_g.plot(alpha = 0.2, ax = ax, edgecolor = 'grey')
listing.plot(markersize = 0.4, color = 'black', alpha = 0.2, ax = ax)
# Out:
# <AxesSubplot: title={'center': '2022 New York City Airbnb Listing'}, xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# ### 4.4 Choropleth Map on the Number of Listing (8 points)
# Plot the number of listing by census tracts.
# - Change the title to *2022 New York City Airbnb: the Number of Listing by Census Tract* and name the x-y axis as longitude and latitude. (2 points)
# - Use *quantile* as the scheme and specify the quantile number as 5. Use color set *OrRd*. (2 points)
#
# For aesthetic purpose,
# - Add legend to the map and do not let it overlap with any census tract. (2 points)
# - Add *grey* edge color to census tracts and specify the edge width as 0.2. (2 points)

# %%
import mapclassify
fig, ax = plt.subplots(figsize=(6, 6))
plt.title("2022 New York City Airbnb: the Number of Listing by Census Tract")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

ct_demo_g_count.plot(column='tract_list_count',
                ax= ax,
                legend=True,
                scheme= 'Quantiles',
                k = 5,
                cmap='OrRd',
                edgecolor = 'grey',
                linewidth = 0.2,
                legend_kwds={'loc': 'upper left'})
# Out:
# <AxesSubplot: title={'center': '2022 New York City Airbnb: the Number of Listing by Census Tract'}, xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# ### 4.4 Choropleth Map on the Median Housing Value (2 points)
# Plot the median housing value by census tracts.
# - Change the title to *2022 New York City Airbnb: the Median Housing Value by Census Tract* and name the x-y axis as longitude and latitude.
# - Use *quantile* as the scheme and specify the quantile number as 5. Use color set *OrRd*.
#
# For aesthetic purpose,
# - Add legend to the map and do not let it overlap with any census tract.
# - Add *grey* edge color to census tracts and specify the edge width as 0.2.

# %%
### enter your code here
fig, ax = plt.subplots(figsize=(6, 6))
plt.title("2022 New York City Airbnb: the Median Housing Value by Census Tract")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

ct_demo_g_count.plot(column='house_value',
                ax= ax,
                legend=True,
                scheme= 'Quantiles',
                k = 5,
                cmap='OrRd',
                edgecolor = 'grey',
                linewidth = 0.2,
                legend_kwds={'loc': 'upper left'})
# Out:
# <AxesSubplot: title={'center': '2022 New York City Airbnb: the Median Housing Value by Census Tract'}, xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# ### 4.4 Choropleth Map on the Median Household Income (2 points)
# Plot the median household income by census tracts.
# - Change the title to *2022 New York City Airbnb: the Median Household Income by Census Tract* and name the x-y axis as longitude and latitude.
# - Use quantile as the scheme and specify the quantile number as 5. Use color set *BuPu*.
#
# For aesthetic purpose,
# - Add legend to the map and do not let it overlap with any census tract.
# - Add grey edge color to census tracts and specify the edge width as 0.2.

# %%
### enter your code here
fig, ax = plt.subplots(figsize=(6, 6))
plt.title("2022 New York City Airbnb: the Median Household Income by Census Tract")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

ct_demo_g_count.plot(column='hh_income',
                ax= ax,
                legend=True,
                scheme= 'Quantiles',
                k = 5,
                cmap='OrRd',
                edgecolor = 'grey',
                linewidth = 0.2,
                legend_kwds={'loc': 'upper left'})
# Out:
# <AxesSubplot: title={'center': '2022 New York City Airbnb: the Median Household Income by Census Tract'}, xlabel='Longitude', ylabel='Latitude'>
